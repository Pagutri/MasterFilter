# %% [markdown]
# ### Probando el módulo filtros.py

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import filtros

# %% [markdown]
# Probando el pasabajos:

# %%
img_prueba = cv2.imread('imagenes/prueba.tif', 0)
M, N = img_prueba.shape

# %%
ker_ideal_pasabajos = filtros.kernel_pasabajos(M, N)
ker_gauss_pasabajos = filtros.kernel_pasabajos(M, N, forma = 1)
ker_btw_pasabajos = filtros.kernel_pasabajos(M, N, forma = 2)

# %%
prueba_ideal_pasabajos = filtros.aplicar_filtro(img_prueba, ker_ideal_pasabajos)
prueba_gauss_pasabajos = filtros.aplicar_filtro(img_prueba, ker_gauss_pasabajos)
prueba_btw_pasabajos = filtros.aplicar_filtro(img_prueba, ker_btw_pasabajos)

# %%
fig = plt.figure(figsize = (15, 10))
fig.add_subplot(1, 4, 1)
plt.imshow(img_prueba, cmap = 'gray')
plt.title('Imagen original', size = 18);
fig.add_subplot(1, 4, 2)
plt.imshow(prueba_ideal_pasabajos, cmap = 'gray')
plt.title('Pasabajos ideal', size = 18);
fig.add_subplot(1, 4, 3)
plt.imshow(prueba_gauss_pasabajos, cmap = 'gray')
plt.title('Pasabajos gaussiano', size = 18);
fig.add_subplot(1, 4, 4)
plt.imshow(prueba_btw_pasabajos, cmap = 'gray')
plt.title('Pasabajos de Butterworth', size = 18);

# %% [markdown]
# Probando el filtro pasaaltos:

# %%
ker_ideal_pasaaltos = filtros.kernel_pasaaltos(M, N)
ker_gauss_pasaaltos = filtros.kernel_pasaaltos(M, N, forma = 1)
ker_btw_pasaaltos = filtros.kernel_pasaaltos(M, N, forma = 2)

# %%
prueba_ideal_pasaaltos = filtros.aplicar_filtro(img_prueba, ker_ideal_pasaaltos)
prueba_gauss_pasaaltos = filtros.aplicar_filtro(img_prueba, ker_gauss_pasaaltos)
prueba_btw_pasaaltos = filtros.aplicar_filtro(img_prueba, ker_btw_pasaaltos)

# %%
fig = plt.figure(figsize = (15, 10))
fig.add_subplot(1, 4, 1)
plt.imshow(img_prueba, cmap = 'gray')
plt.title('Imagen original', size = 18);
fig.add_subplot(1, 4, 2)
plt.imshow(prueba_ideal_pasaaltos, cmap = 'gray')
plt.title('Pasaaltos ideal', size = 18);
fig.add_subplot(1, 4, 3)
plt.imshow(prueba_gauss_pasaaltos, cmap = 'gray')
plt.title('Pasaaltos gaussiano', size = 18);
fig.add_subplot(1, 4, 4)
plt.imshow(prueba_btw_pasaaltos, cmap = 'gray')
plt.title('Pasaaltos de Butterworth', size = 18);

# %% [markdown]
# Probando el filtro rechazabandas:

# %%
ker_ideal_rechazabandas = filtros.kernel_rechazabandas(M, N, 10, 5)
ker_gauss_rechazabandas = filtros.kernel_rechazabandas(M, N, forma = 1)
ker_btw_rechazabandas = filtros.kernel_rechazabandas(M, N, forma = 2)

# %%
prueba_ideal_rechazabandas = filtros.aplicar_filtro(img_prueba, ker_ideal_rechazabandas)
prueba_gauss_rechazabandas = filtros.aplicar_filtro(img_prueba, ker_gauss_rechazabandas)
prueba_btw_rechazabandas = filtros.aplicar_filtro(img_prueba, ker_btw_rechazabandas)

# %%
fig = plt.figure(figsize = (15, 10))
fig.add_subplot(1, 4, 1)
plt.imshow(img_prueba, cmap = 'gray')
plt.title('Imagen original', size = 18);
fig.add_subplot(1, 4, 2)
plt.imshow(prueba_ideal_rechazabandas, cmap = 'gray')
plt.title('rechazabandas ideal', size = 18);
fig.add_subplot(1, 4, 3)
plt.imshow(prueba_gauss_rechazabandas, cmap = 'gray')
plt.title('rechazabandas gaussiano', size = 18);
fig.add_subplot(1, 4, 4)
plt.imshow(prueba_btw_rechazabandas, cmap = 'gray')
plt.title('rechazabandas de Butterworth', size = 18);

# %% [markdown]
# Probando el filtro pasabandas:

# %%
ker_ideal_pasabandas = filtros.kernel_pasabandas(M, N)
ker_gauss_pasabandas = filtros.kernel_pasabandas(M, N, forma = 1)
ker_btw_pasabandas = filtros.kernel_pasabandas(M, N, forma = 2)

# %%
prueba_ideal_pasabandas = filtros.aplicar_filtro(img_prueba, ker_ideal_pasabandas)
prueba_gauss_pasabandas = filtros.aplicar_filtro(img_prueba, ker_gauss_pasabandas)
prueba_btw_pasabandas = filtros.aplicar_filtro(img_prueba, ker_btw_pasabandas)

# %%
fig = plt.figure(figsize = (15, 10))
fig.add_subplot(1, 4, 1)
plt.imshow(img_prueba, cmap = 'gray')
plt.title('Imagen original', size = 18);
fig.add_subplot(1, 4, 2)
plt.imshow(prueba_ideal_pasabandas, cmap = 'gray')
plt.title('pasabandas ideal', size = 18);
fig.add_subplot(1, 4, 3)
plt.imshow(prueba_gauss_pasabandas, cmap = 'gray')
plt.title('pasabandas gaussiano', size = 18);
fig.add_subplot(1, 4, 4)
plt.imshow(prueba_btw_pasabandas, cmap = 'gray')
plt.title('pasabandas de Butterworth', size = 18);
